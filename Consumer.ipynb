# %%
from kafka import KafkaConsumer
from time import sleep
from json import dumps,loads
import json
from s3fs import S3FileSystem

# %%
consumer = KafkaConsumer(
    'telebot-topic1',
     bootstrap_servers=['54.221.178.60:9092'], 
    value_deserializer=lambda x: loads(x.decode('utf-8')))

# %%
for c in consumer:
    print(c.value)
# Out:
# {'College': 'University of Scranton Scranton city', 'Interview Outcome': 'Approved', 'Visa Attempt Number': 1.0, 'Interview Date': '2023-06-06', 'Interview Time': '09:30', 'Interview City': 'Hyderabad', 'Interview Country': 'India', 'Exam Type': 'Others', 'Exam Score': 0.0, 'English Test Type': 'Dulingo', 'English Test Score': 130.0, 'Grad Level': 'Bachelors-3', 'Grad Major': 'Bcom Finance and cost accountancy', 'Grad GPA': 5.5, 'Grad Institute': 'Indira Gandhi National open University', 'Grad Country': 'India\n\n        Job Profile', 'Job Type': 'Senior audit executive', 'Job Years': 2.0}
# {'College': 'THE Jhons Hopkins University', 'Interview Outcome': 'Approved', 'Visa Attempt Number': 1.0, 'Interview Date': '2023-06-07', 'Interview Time': '8:00', 'Interview City': 'Hyderabad', 'Interview Country': 'India', 'Exam Type': 'Others', 'Exam Score': 0.0, 'English Test Type': 'TOEFL', 'English Test Score': 104.0, 'Grad Level': 'Others', 'Grad Major': 'M.B.B.S', 'Grad GPA': 4.0, 'Grad Institute': 'KLE', 'Grad Country': 'India\n\n        Job Profile', 'Job Type': 'Doctor', 'Job Years': 1.0}
# {'College': 'Auburn university', 'Interview Outcome': 'Rejected', 'Visa Attempt Number': 1.0, 'Interview Date': '2023-06-01', 'Interview Time': '11:00', 'Interview City': 'Chennai', 'Interview Country': 'India', 'Exam Type': 'Exempt', 'Exam Score': 0.0, 'English Test Type': 'TOEFL', 'English Test Score': 82.0, 'Grad Level': 'Bachelors (4 Years)', 'Grad Major': 'Computer Science', 'Grad GPA': 7.1, 'Grad Institute': 'Nova college of eng', 'Grad Country': 'India\n\n        Job Profile', 'Job Type': 'Software developer', 'Job Years': 3.5}
# {'College': 'George mason University', 'Interview Outcome': 'Approved', 'Visa Attempt Number': 1.0, 'Interview Date': '2023-06-07', 'Interview Time': '11:50', 'Interview City': 'Delhi', 'Interview Country': 'India', 'Exam Type': 'GRE', 'Exam Score': 299.0, 'English Test Type': 'TOEFL', 'English Test Score': 87.0, 'Grad Level': 'Bachelors-4', 'Grad Major': 'Computer science and engineering', 'Grad GPA': 8.0, 'Grad Institute': 'Pes college of engineering', 'Grad Country': 'India\n\n        Job Profile', 'Job Type': 'Application development analyst', 'Job Years': 2.4}
# {'College': 'University of Dayton', 'Interview Outcome': 'Approved', 'Visa Attempt Number': 1.0, 'Interview Date': '2023-06-07', 'Interview Time': '11:50', 'Interview City': 'Delhi', 'Interview Country': 'India', 'Exam Type': 'GRE', 'Exam Score': 320.0, 'English Test Type': 'Dulingo', 'English Test Score': 125.0, 'Grad Level': 'Bachelors (4 Years)', 'Grad Major': 'Electronic and communication engineering', 'Grad GPA': 6.42, 'Grad Institute': 'GURUNANAK INSTITUTE OF TECHNICAL CAMPUS', 'Grad Country': 'India\n\n        Job Profile', 'Job Type': 'Intern', 'Job Years': 6.0}
# {'College': 'University of central missouri', 'Interview Outcome': 'Approved', 'Visa Attempt Number': 1.0, 'Interview Date': '2023-06-07', 'Interview Time': '11:50', 'Interview City': 'Delhi', 'Interview Country': 'India', 'Exam Type': 'GRE', 'Exam Score': 318.0, 'English Test Type': 'IELTS', 'English Test Score': 7.0, 'Grad Level': 'Bachelors-4', 'Grad Major': 'Electronics and communication engineering', 'Grad GPA': 6.3, 'Grad Institute': 'Lovely professional University', 'Grad Country': 'India\n\n        Job Profile', 'Job Type': 'Cloud data engineer', 'Job Years': 2.8}
# {'College': 'University of north Texas', 'Interview Outcome': 'Approved', 'Visa Attempt Number': 1.0, 'Interview Date': '2023-06-08', 'Interview Time': '08:30', 'Interview City': 'Chennai', 'Interview Country': 'India ', 'Exam Type': 'GRE', 'Exam Score': 316.0, 'English Test Type': 'Dulingo', 'English Test Score': 110.0, 'Grad Level': 'Bachelors-4', 'Grad Major': 'computer science and engineering', 'Grad GPA': 7.3, 'Grad Institute': 'Mallareddy engineering college for women', 'Grad Country': 'India\n\n        Job Profile', 'Job Type': nan, 'Job Years': 1.8}
# {'College': 'Purdue', 'Interview Outcome': 'Approved', 'Visa Attempt Number': 1.0, 'Interview Date': '2023-06-07', 'Interview Time': '10:20', 'Interview City': 'Mumbai', 'Interview Country': 'India', 'Exam Type': 'GRE', 'Exam Score': 313.0, 'English Test Type': 'IELTS', 'English Test Score': 8.0, 'Grad Level': 'Bachelors (4 Years)', 'Grad Major': 'Production Engg', 'Grad GPA': 9.05, 'Grad Institute': 'FRCRCE', 'Grad Country': 'India\n\n        Job Profile', 'Job Type': 'Mechanical Production Engg', 'Job Years': 1.7}
# {'College': 'Pittsburgh State University', 'Interview Outcome': 'Approved', 'Visa Attempt Number': 1.0, 'Interview Date': '2023-06-08', 'Interview Time': '08:40', 'Interview City': 'Delhi', 'Interview Country': 'India', 'Exam Type': 'Exempt', 'Exam Score': 0.0, 'English Test Type': 'IELTS', 'English Test Score': 6.5, 'Grad Level': 'Bachelors (3 Years)', 'Grad Major': 'BBA-MA', 'Grad GPA': 6.39, 'Grad Institute': 'Gitam University Hyderabad', 'Grad Country': 'India\n\n        Job Profile', 'Job Type': 'Quality Specialist', 'Job Years': 1.5}
# {'College': 'University of Wisconsin', 'Interview Outcome': 'Approved', 'Visa Attempt Number': 1.0, 'Interview Date': '2023-06-07', 'Interview Time': '08:45', 'Interview City': 'Kolkata', 'Interview Country': 'Kolkata', 'Exam Type': 'Exempt', 'Exam Score': 0.0, 'English Test Type': 'Dulingo', 'English Test Score': 125.0, 'Grad Level': 'Bachelors (4 Years)', 'Grad Major': 'Computer Science and Engineering', 'Grad GPA': 6.63, 'Grad Institute': 'Lovely Professional University', 'Grad Country': 'India\n\n        Job Profile', 'Job Type': 'Software Engineer', 'Job Years': 2.0}
# {'College': 'Valparaiso university', 'Interview Outcome': 'Rejected', 'Visa Attempt Number': 2.0, 'Interview Date': '2023-07-11', 'Interview Time': '10:30', 'Interview City': 'Chennai', 'Interview Country': 'India', 'Exam Type': 'Exempt', 'Exam Score': 0.0, 'English Test Type': 'Dulingo', 'English Test Score': 115.0, 'Grad Level': 'Bachelors-3', 'Grad Major': 'Computer Applications', 'Grad GPA': 8.33, 'Grad Institute': 'Osmania University', 'Grad Country': 'India\n\n        Job Profile', 'Job Type': nan, 'Job Years': 0.0}
# {'College': 'Rutgers University', 'Interview Outcome': 'Approved', 'Visa Attempt Number': 1.0, 'Interview Date': '2023-06-07', 'Interview Time': '11:30', 'Interview City': 'Chennai', 'Interview Country': 'USA', 'Exam Type': 'Exempt', 'Exam Score': 0.0, 'English Test Type': 'TOEFL', 'English Test Score': 105.0, 'Grad Level': 'Masters', 'Grad Major': 'PHARM D', 'Grad GPA': 8.2, 'Grad Institute': 'JSS ACADEMY OF HIGHER EDUCATION AND RESEARCH', 'Grad Country': 'India\n\n        Job Profile', 'Job Type': 'Clinical Data Scientist', 'Job Years': 2.5}
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-5-d718415e1172> in <module>
# ----> 1 for c in consumer:
#       2     print(c.value)
#
# c:\users\vsneh\appdata\local\programs\python\python37\lib\site-packages\kafka\consumer\group.py in __next__(self)
#    1191             return self.next_v1()
#    1192         else:
# -> 1193             return self.next_v2()
#    1194
#    1195     def next_v2(self):
#
# c:\users\vsneh\appdata\local\programs\python\python37\lib\site-packages\kafka\consumer\group.py in next_v2(self)
#    1199                 self._iterator = self._message_generator_v2()
#    1200             try:
# -> 1201                 return next(self._iterator)
#    1202             except StopIteration:
#    1203                 self._iterator = None
#
# c:\users\vsneh\appdata\local\programs\python\python37\lib\site-packages\kafka\consumer\group.py in _message_generator_v2(self)
#    1114     def _message_generator_v2(self):
#    1115         timeout_ms = 1000 * (self._consumer_timeout - time.time())
# -> 1116         record_map = self.poll(timeout_ms=timeout_ms, update_offsets=False)
#    1117         for tp, records in six.iteritems(record_map):
#    1118             # Generators are stateful, and it is possible that the tp / records
#
# c:\users\vsneh\appdata\local\programs\python\python37\lib\site-packages\kafka\consumer\group.py in poll(self, timeout_ms, max_records, update_offsets)
#     653         remaining = timeout_ms
#     654         while True:
# --> 655             records = self._poll_once(remaining, max_records, update_offsets=update_offsets)
#     656             if records:
#     657                 return records
#
# c:\users\vsneh\appdata\local\programs\python\python37\lib\site-packages\kafka\consumer\group.py in _poll_once(self, timeout_ms, max_records, update_offsets)
#     700
#     701         timeout_ms = min(timeout_ms, self._coordinator.time_to_next_poll() * 1000)
# --> 702         self._client.poll(timeout_ms=timeout_ms)
#     703         # after the long poll, we should check whether the group needs to rebalance
#     704         # prior to returning data so that the group can stabilize faster
#
# c:\users\vsneh\appdata\local\programs\python\python37\lib\site-packages\kafka\client_async.py in poll(self, timeout_ms, future)
#     600                     timeout = max(0, timeout)  # avoid negative timeouts
#     601
# --> 602                 self._poll(timeout / 1000)
#     603
#     604             # called without the lock to avoid deadlock potential
#
# c:\users\vsneh\appdata\local\programs\python\python37\lib\site-packages\kafka\client_async.py in _poll(self, timeout)
#     632
#     633         start_select = time.time()
# --> 634         ready = self._selector.select(timeout)
#     635         end_select = time.time()
#     636         if self._sensors:
#
# c:\users\vsneh\appdata\local\programs\python\python37\lib\selectors.py in select(self, timeout)
#     321         ready = []
#     322         try:
# --> 323             r, w, _ = self._select(self._readers, self._writers, [], timeout)
#     324         except InterruptedError:
#     325             return ready
#
# c:\users\vsneh\appdata\local\programs\python\python37\lib\selectors.py in _select(self, r, w, _, timeout)
#     312     if sys.platform == 'win32':
#     313         def _select(self, r, w, _, timeout=None):
# --> 314             r, w, x = select.select(r, w, w, timeout)
#     315             return r, w + x, []
#     316     else:
#
# KeyboardInterrupt:

# %%
s3 = S3FileSystem()

# %%
for count, i in enumerate(consumer):
    with s3.open("s3://telebot-snehit/teleBot-row_{}.json".format(count), 'w') as file:
        json.dump(i.value, file)
        print(count, i.value)
# Out:
# 0 {'College': 'University of Dayton', 'Interview Outcome': 'Approved', 'Visa Attempt Number': 1.0, 'Interview Date': '2023-06-07', 'Interview Time': '11:50', 'Interview City': 'Delhi', 'Interview Country': 'India', 'Exam Type': 'GRE', 'Exam Score': 320.0, 'English Test Type': 'Dulingo', 'English Test Score': 125.0, 'Grad Level': 'Bachelors (4 Years)', 'Grad Major': 'Electronic and communication engineering', 'Grad GPA': 6.42, 'Grad Institute': 'GURUNANAK INSTITUTE OF TECHNICAL CAMPUS', 'Grad Country': 'India\n\n        Job Profile', 'Job Type': 'Intern', 'Job Years': 6.0}
# 1 {'College': 'Pace University', 'Interview Outcome': 'Approved', 'Visa Attempt Number': 1.0, 'Interview Date': '2023-06-05', 'Interview Time': '09:10', 'Interview City': 'Mumbai', 'Interview Country': 'India', 'Exam Type': 'GRE', 'Exam Score': 296.0, 'English Test Type': 'IELTS', 'English Test Score': 7.0, 'Grad Level': 'Bachelors-4', 'Grad Major': 'Electronics and Telecommunications', 'Grad GPA': 7.7, 'Grad Institute': 'Yeshwantrao Chawan College of Engineering Nagpur', 'Grad Country': 'India\n\n        Job Profile', 'Job Type': 'Software Engineer', 'Job Years': 1.0}
# 2 {'College': 'George Washington University', 'Interview Outcome': 'Approved', 'Visa Attempt Number': 1.0, 'Interview Date': '2023-06-07', 'Interview Time': '12:00', 'Interview City': 'Mumbai', 'Interview Country': 'India', 'Exam Type': 'GRE', 'Exam Score': 300.0, 'English Test Type': 'IELTS', 'English Test Score': 7.0, 'Grad Level': 'Bachelors (4 Years)', 'Grad Major': 'Computer Engineering', 'Grad GPA': 8.85, 'Grad Institute': 'VCET', 'Grad Country': 'India\n\n        Job Profile', 'Job Type': 'Student', 'Job Years': 0.0}
# 3 {'College': 'New Haven', 'Interview Outcome': 'Approved', 'Visa Attempt Number': 1.0, 'Interview Date': '2023-06-07', 'Interview Time': '9.15', 'Interview City': 'Chennai', 'Interview Country': 'India', 'Exam Type': 'GRE', 'Exam Score': 319.0, 'English Test Type': 'Dulingo', 'English Test Score': 110.0, 'Grad Level': 'Bachelors (4 Years)', 'Grad Major': 'Mechanical engineering', 'Grad GPA': 8.01, 'Grad Institute': 'KL University', 'Grad Country': 'India\n\n        Job Profile', 'Job Type': 'Business analyst at Genpact', 'Job Years': 3.3}
# 4 {'College': 'Valparaiso university', 'Interview Outcome': 'Rejected', 'Visa Attempt Number': 2.0, 'Interview Date': '2023-07-11', 'Interview Time': '10:30', 'Interview City': 'Chennai', 'Interview Country': 'India', 'Exam Type': 'Exempt', 'Exam Score': 0.0, 'English Test Type': 'Dulingo', 'English Test Score': 115.0, 'Grad Level': 'Bachelors-3', 'Grad Major': 'Computer Applications', 'Grad GPA': 8.33, 'Grad Institute': 'Osmania University', 'Grad Country': 'India\n\n        Job Profile', 'Job Type': nan, 'Job Years': 0.0}
# 5 {'College': 'THE Jhons Hopkins University', 'Interview Outcome': 'Approved', 'Visa Attempt Number': 1.0, 'Interview Date': '2023-06-07', 'Interview Time': '8:00', 'Interview City': 'Hyderabad', 'Interview Country': 'India', 'Exam Type': 'Others', 'Exam Score': 0.0, 'English Test Type': 'TOEFL', 'English Test Score': 104.0, 'Grad Level': 'Others', 'Grad Major': 'M.B.B.S', 'Grad GPA': 4.0, 'Grad Institute': 'KLE', 'Grad Country': 'India\n\n        Job Profile', 'Job Type': 'Doctor', 'Job Years': 1.0}
# 6 {'College': 'New Haven', 'Interview Outcome': 'Approved', 'Visa Attempt Number': 1.0, 'Interview Date': '2023-06-07', 'Interview Time': '9.15', 'Interview City': 'Chennai', 'Interview Country': 'India', 'Exam Type': 'GRE', 'Exam Score': 319.0, 'English Test Type': 'Dulingo', 'English Test Score': 110.0, 'Grad Level': 'Bachelors (4 Years)', 'Grad Major': 'Mechanical engineering', 'Grad GPA': 8.01, 'Grad Institute': 'KL University', 'Grad Country': 'India\n\n        Job Profile', 'Job Type': 'Business analyst at Genpact', 'Job Years': 3.3}
# 7 {'College': 'Suny Albany', 'Interview Outcome': 'Approved', 'Visa Attempt Number': 1.0, 'Interview Date': '2023-06-08', 'Interview Time': '11:40', 'Interview City': 'Delhi', 'Interview Country': 'India', 'Exam Type': 'GRE', 'Exam Score': 322.0, 'English Test Type': 'Dulingo', 'English Test Score': 135.0, 'Grad Level': 'Bachelors-4', 'Grad Major': 'Electronics and communication engineering', 'Grad GPA': 8.02, 'Grad Institute': 'PvP Siddhartha institute of technology', 'Grad Country': 'India\n\n        Job Profile', 'Job Type': 'Fresher', 'Job Years': 0.0}
# 8 {'College': 'University of Scranton Scranton city', 'Interview Outcome': 'Approved', 'Visa Attempt Number': 1.0, 'Interview Date': '2023-06-06', 'Interview Time': '09:30', 'Interview City': 'Hyderabad', 'Interview Country': 'India', 'Exam Type': 'Others', 'Exam Score': 0.0, 'English Test Type': 'Dulingo', 'English Test Score': 130.0, 'Grad Level': 'Bachelors-3', 'Grad Major': 'Bcom Finance and cost accountancy', 'Grad GPA': 5.5, 'Grad Institute': 'Indira Gandhi National open University', 'Grad Country': 'India\n\n        Job Profile', 'Job Type': 'Senior audit executive', 'Job Years': 2.0}
# 9 {'College': 'New Haven', 'Interview Outcome': 'Approved', 'Visa Attempt Number': 1.0, 'Interview Date': '2023-06-07', 'Interview Time': '9.15', 'Interview City': 'Chennai', 'Interview Country': 'India', 'Exam Type': 'GRE', 'Exam Score': 319.0, 'English Test Type': 'Dulingo', 'English Test Score': 110.0, 'Grad Level': 'Bachelors (4 Years)', 'Grad Major': 'Mechanical engineering', 'Grad GPA': 8.01, 'Grad Institute': 'KL University', 'Grad Country': 'India\n\n        Job Profile', 'Job Type': 'Business analyst at Genpact', 'Job Years': 3.3}
# 10 {'College': 'Lamar university', 'Interview Outcome': 'Approved', 'Visa Attempt Number': 1.0, 'Interview Date': '2023-06-07', 'Interview Time': '10:00', 'Interview City': 'CHENNAI', 'Interview Country': 'INDIA', 'Exam Type': 'GRE', 'Exam Score': 321.0, 'English Test Type': 'TOEFL', 'English Test Score': 90.0, 'Grad Level': 'Bachelors (4 Years)', 'Grad Major': 'Mechanical engineering', 'Grad GPA': 6.7, 'Grad Institute': 'Jawaharlal Nehru Technological University', 'Grad Country': 'INDIA\n\n        Job Profile', 'Job Type': 'Senior software engineer', 'Job Years': 5.0}
# 11 {'College': 'Stevens Institute of Technology', 'Interview Outcome': 'Approved', 'Visa Attempt Number': 1.0, 'Interview Date': '2023-06-02', 'Interview Time': '11:20', 'Interview City': 'Delhi', 'Interview Country': 'India', 'Exam Type': 'GRE', 'Exam Score': 320.0, 'English Test Type': 'IELTS', 'English Test Score': 6.5, 'Grad Level': 'Bachelors (3 Years)', 'Grad Major': 'Bachelors of Commerce', 'Grad GPA': 7.8, 'Grad Institute': 'Osmania university', 'Grad Country': 'India\n\n        Job Profile', 'Job Type': 'Data analyst', 'Job Years': 1.5}
# 12 {'College': 'Missouri State University', 'Interview Outcome': 'Rejected', 'Visa Attempt Number': 2.0, 'Interview Date': '2023-07-11', 'Interview Time': '10:30', 'Interview City': 'Chennai', 'Interview Country': 'India', 'Exam Type': 'Others', 'Exam Score': 6.0, 'English Test Type': 'IELTS', 'English Test Score': 6.0, 'Grad Level': 'Bachelors-3', 'Grad Major': "Bachelor's In Hotel Management", 'Grad GPA': 8.36, 'Grad Institute': 'Sun international institute of management and technology', 'Grad Country': 'India\n\n        Job Profile', 'Job Type': 'Genpact as a Process Associate', 'Job Years': 0.6}
# 13 {'College': 'Suny Albany', 'Interview Outcome': 'Approved', 'Visa Attempt Number': 1.0, 'Interview Date': '2023-06-08', 'Interview Time': '11:40', 'Interview City': 'Delhi', 'Interview Country': 'India', 'Exam Type': 'GRE', 'Exam Score': 322.0, 'English Test Type': 'Dulingo', 'English Test Score': 135.0, 'Grad Level': 'Bachelors-4', 'Grad Major': 'Electronics and communication engineering', 'Grad GPA': 8.02, 'Grad Institute': 'PvP Siddhartha institute of technology', 'Grad Country': 'India\n\n        Job Profile', 'Job Type': 'Fresher', 'Job Years': 0.0}
# 14 {'College': 'University of Wisconsin', 'Interview Outcome': 'Approved', 'Visa Attempt Number': 1.0, 'Interview Date': '2023-06-07', 'Interview Time': '08:45', 'Interview City': 'Kolkata', 'Interview Country': 'Kolkata', 'Exam Type': 'Exempt', 'Exam Score': 0.0, 'English Test Type': 'Dulingo', 'English Test Score': 125.0, 'Grad Level': 'Bachelors (4 Years)', 'Grad Major': 'Computer Science and Engineering', 'Grad GPA': 6.63, 'Grad Institute': 'Lovely Professional University', 'Grad Country': 'India\n\n        Job Profile', 'Job Type': 'Software Engineer', 'Job Years': 2.0}
# 15 {'College': 'Concordia St Paul university', 'Interview Outcome': 'Approved', 'Visa Attempt Number': 1.0, 'Interview Date': '2023-06-07', 'Interview Time': '11:30', 'Interview City': 'Delhi', 'Interview Country': 'India', 'Exam Type': 'Others', 'Exam Score': 0.0, 'English Test Type': 'TOEFL', 'English Test Score': 90.0, 'Grad Level': 'Bachelors (4 Years)', 'Grad Major': 'Electronics and Communication Engineering', 'Grad GPA': 7.22, 'Grad Institute': 'Sai Tirumala NVR Engineering College', 'Grad Country': 'India\n\n        Job Profile', 'Job Type': 'IT Analyst', 'Job Years': 1.0}
# 16 {'College': 'University of North Texas', 'Interview Outcome': 'Approved', 'Visa Attempt Number': 1.0, 'Interview Date': '2023-06-07', 'Interview Time': '10:00', 'Interview City': 'Hyderabad', 'Interview Country': 'India', 'Exam Type': 'Exempt', 'Exam Score': 0.0, 'English Test Type': 'IELTS', 'English Test Score': 8.0, 'Grad Level': 'Bachelors-4', 'Grad Major': 'Information Technology', 'Grad GPA': 6.7, 'Grad Institute': 'Muffakham Jah college of Engineering and Technology', 'Grad Country': 'India\n\n        Job Profile', 'Job Type': 'IT Engineer', 'Job Years': 3.5}
# 17 {'College': 'Babson College', 'Interview Outcome': 'Approved', 'Visa Attempt Number': 1.0, 'Interview Date': '2023-06-07', 'Interview Time': '9:30', 'Interview City': 'Mumbai', 'Interview Country': 'India', 'Exam Type': 'Exempt', 'Exam Score': 0.0, 'English Test Type': 'IELTS', 'English Test Score': 7.0, 'Grad Level': 'Masters', 'Grad Major': 'Computer Science Engineering', 'Grad GPA': 7.65, 'Grad Institute': 'NIT Allahabad', 'Grad Country': 'India\n\n        Job Profile', 'Job Type': 'Senior Software Engineer', 'Job Years': 5.0}
# 18 {'College': 'Lewis University', 'Interview Outcome': 'Approved', 'Visa Attempt Number': 1.0, 'Interview Date': '2023-06-06', 'Interview Time': '09.30', 'Interview City': 'Mumbai', 'Interview Country': 'India', 'Exam Type': 'Exempt', 'Exam Score': 0.0, 'English Test Type': 'Dulingo', 'English Test Score': 120.0, 'Grad Level': 'Bachelors (3 Years)', 'Grad Major': 'Commerce', 'Grad GPA': 6.0, 'Grad Institute': 'Osmania University', 'Grad Country': 'India\n\n        Job Profile', 'Job Type': 'IT Support Specialist', 'Job Years': 9.6}
# 19 {'College': 'Lewis university location Romeoville', 'Interview Outcome': 'Rejected', 'Visa Attempt Number': 1.0, 'Interview Date': '2023-07-06', 'Interview Time': '8:30', 'Interview City': 'Mumbai', 'Interview Country': 'Usa', 'Exam Type': 'Exempt', 'Exam Score': 160.0, 'English Test Type': 'Dulingo', 'English Test Score': 145.0, 'Grad Level': 'Bachelors-3', 'Grad Major': 'B.Com', 'Grad GPA': 8.1, 'Grad Institute': 'Osmania university', 'Grad Country': 'India \n\n        Job Profile', 'Job Type': 'Gampact company', 'Job Years': 2.5}
# 20 {'College': 'Missouri University of Science and Technology', 'Interview Outcome': 'Approved', 'Visa Attempt Number': 1.0, 'Interview Date': '2023-06-06', 'Interview Time': '08:40', 'Interview City': 'Delhi', 'Interview Country': 'No 12', 'Exam Type': 'GRE', 'Exam Score': 319.0, 'English Test Type': 'Dulingo', 'English Test Score': 120.0, 'Grad Level': 'Bachelors (4 Years)', 'Grad Major': 'Electronics and Communication Engineering', 'Grad GPA': 7.0, 'Grad Institute': 'Geethanjali collage of engineering and technology', 'Grad Country': 'India\n\n        Job Profile', 'Job Type': 'Jr Security analyst', 'Job Years': 0.7}
# 21 {'College': 'Concordia St Paul university', 'Interview Outcome': 'Approved', 'Visa Attempt Number': 1.0, 'Interview Date': '2023-06-07', 'Interview Time': '11:30', 'Interview City': 'Delhi', 'Interview Country': 'India', 'Exam Type': 'Others', 'Exam Score': 0.0, 'English Test Type': 'TOEFL', 'English Test Score': 90.0, 'Grad Level': 'Bachelors (4 Years)', 'Grad Major': 'Electronics and Communication Engineering', 'Grad GPA': 7.22, 'Grad Institute': 'Sai Tirumala NVR Engineering College', 'Grad Country': 'India\n\n        Job Profile', 'Job Type': 'IT Analyst', 'Job Years': 1.0}
# 22 {'College': 'Missouri University of Science and Technology', 'Interview Outcome': 'Approved', 'Visa Attempt Number': 1.0, 'Interview Date': '2023-06-06', 'Interview Time': '08:40', 'Interview City': 'Delhi', 'Interview Country': 'No 12', 'Exam Type': 'GRE', 'Exam Score': 319.0, 'English Test Type': 'Dulingo', 'English Test Score': 120.0, 'Grad Level': 'Bachelors (4 Years)', 'Grad Major': 'Electronics and Communication Engineering', 'Grad GPA': 7.0, 'Grad Institute': 'Geethanjali collage of engineering and technology', 'Grad Country': 'India\n\n        Job Profile', 'Job Type': 'Jr Security analyst', 'Job Years': 0.7}
# 23 {'College': 'LEWIS UNIVERSITY', 'Interview Outcome': 'Approved', 'Visa Attempt Number': 1.0, 'Interview Date': '2023-06-07', 'Interview Time': '09:45', 'Interview City': 'Delhi', 'Interview Country': 'India', 'Exam Type': 'GRE', 'Exam Score': 322.0, 'English Test Type': 'TOEFL', 'English Test Score': 93.0, 'Grad Level': 'Bachelors-3', 'Grad Major': 'Bachelor of business administration', 'Grad GPA': 5.57, 'Grad Institute': 'SRM INSTITUTION OF SCIENCE AND TECHNOLOGY', 'Grad Country': 'India\n\n        Job Profile', 'Job Type': 'Business development executive', 'Job Years': 2.0}
# 24 {'College': 'Pace University', 'Interview Outcome': 'Approved', 'Visa Attempt Number': 1.0, 'Interview Date': '2023-06-05', 'Interview Time': '09:10', 'Interview City': 'Mumbai', 'Interview Country': 'India', 'Exam Type': 'GRE', 'Exam Score': 296.0, 'English Test Type': 'IELTS', 'English Test Score': 7.0, 'Grad Level': 'Bachelors-4', 'Grad Major': 'Electronics and Telecommunications', 'Grad GPA': 7.7, 'Grad Institute': 'Yeshwantrao Chawan College of Engineering Nagpur', 'Grad Country': 'India\n\n        Job Profile', 'Job Type': 'Software Engineer', 'Job Years': 1.0}
# 25 {'College': 'University of Wisconsin', 'Interview Outcome': 'Approved', 'Visa Attempt Number': 1.0, 'Interview Date': '2023-06-07', 'Interview Time': '08:45', 'Interview City': 'Kolkata', 'Interview Country': 'Kolkata', 'Exam Type': 'Exempt', 'Exam Score': 0.0, 'English Test Type': 'Dulingo', 'English Test Score': 125.0, 'Grad Level': 'Bachelors (4 Years)', 'Grad Major': 'Computer Science and Engineering', 'Grad GPA': 6.63, 'Grad Institute': 'Lovely Professional University', 'Grad Country': 'India\n\n        Job Profile', 'Job Type': 'Software Engineer', 'Job Years': 2.0}
# 26 {'College': 'Adelphi University', 'Interview Outcome': 'Approved', 'Visa Attempt Number': 1.0, 'Interview Date': '2023-06-07', 'Interview Time': '9.15', 'Interview City': 'Mumbai', 'Interview Country': 'India ', 'Exam Type': 'Exempt', 'Exam Score': 0.0, 'English Test Type': 'IELTS', 'English Test Score': 7.5, 'Grad Level': 'Bachelors (3 Years)', 'Grad Major': 'Computer Applications', 'Grad GPA': 7.5, 'Grad Institute': 'University of Mumbai', 'Grad Country': 'India\n\n        Job Profile', 'Job Type': 'Business Analyst', 'Job Years': 1.5}
# 27 {'College': 'Stevens institute of technology', 'Interview Outcome': 'Approved', 'Visa Attempt Number': 1.0, 'Interview Date': '2023-06-07', 'Interview Time': '10:30', 'Interview City': 'Hyderabad', 'Interview Country': 'India', 'Exam Type': 'GRE', 'Exam Score': 310.0, 'English Test Type': 'IELTS', 'English Test Score': 6.5, 'Grad Level': 'Bachelors (4 Years)', 'Grad Major': 'Mechanical Engineering', 'Grad GPA': 6.41, 'Grad Institute': 'SREENIDHI INSTITUTE OF SCIENCE AND TECHNOLOGY', 'Grad Country': 'India\n\n        Job Profile', 'Job Type': 'Nothing', 'Job Years': 0.0}
# 28 {'College': 'Illinois institute of technology', 'Interview Outcome': 'Approved', 'Visa Attempt Number': 1.0, 'Interview Date': '2023-06-07', 'Interview Time': '9:00', 'Interview City': 'Chennai', 'Interview Country': 'India', 'Exam Type': 'Exempt', 'Exam Score': 0.0, 'English Test Type': 'IELTS', 'English Test Score': 6.5, 'Grad Level': 'Bachelors-3', 'Grad Major': 'Risk management finance', 'Grad GPA': 6.9, 'Grad Institute': 'Jain university', 'Grad Country': 'India\n\n        Job Profile', 'Job Type': 'Audit executive', 'Job Years': 4.0}
# 29 {'College': 'Lewis University', 'Interview Outcome': 'Approved', 'Visa Attempt Number': 1.0, 'Interview Date': '2023-06-06', 'Interview Time': '09.30', 'Interview City': 'Mumbai', 'Interview Country': 'India', 'Exam Type': 'Exempt', 'Exam Score': 0.0, 'English Test Type': 'Dulingo', 'English Test Score': 120.0, 'Grad Level': 'Bachelors (3 Years)', 'Grad Major': 'Commerce', 'Grad GPA': 6.0, 'Grad Institute': 'Osmania University', 'Grad Country': 'India\n\n        Job Profile', 'Job Type': 'IT Support Specialist', 'Job Years': 9.6}
# 30 {'College': 'Missouri University of Science and Technology', 'Interview Outcome': 'Approved', 'Visa Attempt Number': 1.0, 'Interview Date': '2023-06-06', 'Interview Time': '08:40', 'Interview City': 'Delhi', 'Interview Country': 'No 12', 'Exam Type': 'GRE', 'Exam Score': 319.0, 'English Test Type': 'Dulingo', 'English Test Score': 120.0, 'Grad Level': 'Bachelors (4 Years)', 'Grad Major': 'Electronics and Communication Engineering', 'Grad GPA': 7.0, 'Grad Institute': 'Geethanjali collage of engineering and technology', 'Grad Country': 'India\n\n        Job Profile', 'Job Type': 'Jr Security analyst', 'Job Years': 0.7}
# 31 {'College': 'Hofstra University', 'Interview Outcome': 'Approved', 'Visa Attempt Number': 1.0, 'Interview Date': '2023-06-07', 'Interview Time': '9:50', 'Interview City': 'New Delhi', 'Interview Country': 'New Delhi ', 'Exam Type': 'GRE', 'Exam Score': 315.0, 'English Test Type': 'TOEFL', 'English Test Score': 89.0, 'Grad Level': 'Bachelors (4 Years)', 'Grad Major': 'B pharmacy', 'Grad GPA': 7.0, 'Grad Institute': 'Anurag group of institutions', 'Grad Country': 'India\n\n        Job Profile', 'Job Type': 'Medical coder', 'Job Years': 1.0}
# 32 {'College': 'Dallas Baptist University', 'Interview Outcome': 'Approved', 'Visa Attempt Number': 1.0, 'Interview Date': '2023-06-07', 'Interview Time': '09:30', 'Interview City': 'Hyderabad', 'Interview Country': 'India', 'Exam Type': 'Exempt', 'Exam Score': 0.0, 'English Test Type': 'IELTS', 'English Test Score': 7.0, 'Grad Level': 'Bachelors (4 Years)', 'Grad Major': 'E.C.E', 'Grad GPA': 6.7, 'Grad Institute': 'JB Institute of Engineering and Technology', 'Grad Country': 'India\n\n        Job Profile', 'Job Type': 'Business systems Analyst', 'Job Years': 2.1}
# 33 {'College': 'Hofstra University', 'Interview Outcome': 'Approved', 'Visa Attempt Number': 1.0, 'Interview Date': '2023-06-07', 'Interview Time': '9:50', 'Interview City': 'New Delhi', 'Interview Country': 'New Delhi ', 'Exam Type': 'GRE', 'Exam Score': 315.0, 'English Test Type': 'TOEFL', 'English Test Score': 89.0, 'Grad Level': 'Bachelors (4 Years)', 'Grad Major': 'B pharmacy', 'Grad GPA': 7.0, 'Grad Institute': 'Anurag group of institutions', 'Grad Country': 'India\n\n        Job Profile', 'Job Type': 'Medical coder', 'Job Years': 1.0}
# 34 {'College': 'Troy University', 'Interview Outcome': 'Rejected', 'Visa Attempt Number': 1.0, 'Interview Date': '2023-06-08', 'Interview Time': '10:30', 'Interview City': 'Hyderabad', 'Interview Country': 'India ', 'Exam Type': 'Exempt', 'Exam Score': 0.0, 'English Test Type': 'Dulingo', 'English Test Score': 125.0, 'Grad Level': 'Bachelors-4', 'Grad Major': 'computer science', 'Grad GPA': 6.5, 'Grad Institute': 'Jain University bangalore', 'Grad Country': 'india\n\n        Job Profile', 'Job Type': 'azure infrastructure engineer', 'Job Years': 2.5}
# 35 {'College': 'Illinois institute of technology', 'Interview Outcome': 'Approved', 'Visa Attempt Number': 1.0, 'Interview Date': '2023-06-07', 'Interview Time': '9:00', 'Interview City': 'Chennai', 'Interview Country': 'India', 'Exam Type': 'Exempt', 'Exam Score': 0.0, 'English Test Type': 'IELTS', 'English Test Score': 6.5, 'Grad Level': 'Bachelors-3', 'Grad Major': 'Risk management finance', 'Grad GPA': 6.9, 'Grad Institute': 'Jain university', 'Grad Country': 'India\n\n        Job Profile', 'Job Type': 'Audit executive', 'Job Years': 4.0}
# 36 {'College': 'Concordia university St Paul', 'Interview Outcome': 'Rejected', 'Visa Attempt Number': 1.0, 'Interview Date': '2023-07-10', 'Interview Time': '8:30', 'Interview City': 'Chennai', 'Interview Country': 'American Nigerian', 'Exam Type': 'GRE', 'Exam Score': 318.0, 'English Test Type': 'Dulingo', 'English Test Score': 105.0, 'Grad Level': 'Bachelors (4 Years)', 'Grad Major': 'Computer science', 'Grad GPA': 6.5, 'Grad Institute': 'Jntu h', 'Grad Country': 'India\n\n        Job Profile', 'Job Type': 'Data analyst', 'Job Years': 5.3}
# 37 {'College': 'Dallas Baptist University', 'Interview Outcome': 'Approved', 'Visa Attempt Number': 1.0, 'Interview Date': '2023-06-07', 'Interview Time': '09:30', 'Interview City': 'Hyderabad', 'Interview Country': 'India', 'Exam Type': 'Exempt', 'Exam Score': 0.0, 'English Test Type': 'IELTS', 'English Test Score': 7.0, 'Grad Level': 'Bachelors (4 Years)', 'Grad Major': 'E.C.E', 'Grad GPA': 6.7, 'Grad Institute': 'JB Institute of Engineering and Technology', 'Grad Country': 'India\n\n        Job Profile', 'Job Type': 'Business systems Analyst', 'Job Years': 2.1}
# 38 {'College': 'New York Institute of Technology', 'Interview Outcome': 'Rejected', 'Visa Attempt Number': 2.0, 'Interview Date': '2023-07-10', 'Interview Time': '12:00', 'Interview City': 'Chennai', 'Interview Country': 'India', 'Exam Type': 'Others', 'Exam Score': 84.0, 'English Test Type': 'TOEFL', 'English Test Score': 84.0, 'Grad Level': 'Bachelors-3', 'Grad Major': 'Commerce', 'Grad GPA': 7.98, 'Grad Institute': 'Osmania University', 'Grad Country': 'India\n\n        Job Profile', 'Job Type': 'No Experience', 'Job Years': 0.0}
# 39 {'College': 'Rutgers University', 'Interview Outcome': 'Approved', 'Visa Attempt Number': 1.0, 'Interview Date': '2023-06-07', 'Interview Time': '11:30', 'Interview City': 'Chennai', 'Interview Country': 'USA', 'Exam Type': 'Exempt', 'Exam Score': 0.0, 'English Test Type': 'TOEFL', 'English Test Score': 105.0, 'Grad Level': 'Masters', 'Grad Major': 'PHARM D', 'Grad GPA': 8.2, 'Grad Institute': 'JSS ACADEMY OF HIGHER EDUCATION AND RESEARCH', 'Grad Country': 'India\n\n        Job Profile', 'Job Type': 'Clinical Data Scientist', 'Job Years': 2.5}
# 40 {'College': 'Babson College', 'Interview Outcome': 'Approved', 'Visa Attempt Number': 1.0, 'Interview Date': '2023-06-07', 'Interview Time': '9:30', 'Interview City': 'Mumbai', 'Interview Country': 'India', 'Exam Type': 'Exempt', 'Exam Score': 0.0, 'English Test Type': 'IELTS', 'English Test Score': 7.0, 'Grad Level': 'Masters', 'Grad Major': 'Computer Science Engineering', 'Grad GPA': 7.65, 'Grad Institute': 'NIT Allahabad', 'Grad Country': 'India\n\n        Job Profile', 'Job Type': 'Senior Software Engineer', 'Job Years': 5.0}
# 41 {'College': 'University of Missouri Kansas City', 'Interview Outcome': 'Approved', 'Visa Attempt Number': 1.0, 'Interview Date': '2023-06-07', 'Interview Time': '8:00AM', 'Interview City': 'Chennai', 'Interview Country': 'India', 'Exam Type': 'GRE', 'Exam Score': 320.0, 'English Test Type': 'TOEFL', 'English Test Score': 101.0, 'Grad Level': 'Bachelors-4', 'Grad Major': 'Information and Communication Technology', 'Grad GPA': 7.28, 'Grad Institute': 'SASTRA Deemed to be University', 'Grad Country': 'India\n\n        Job Profile', 'Job Type': 'Software Engineer', 'Job Years': 1.9}
# 42 {'College': 'Stevens institute of technology', 'Interview Outcome': 'Approved', 'Visa Attempt Number': 1.0, 'Interview Date': '2023-06-07', 'Interview Time': '10:30', 'Interview City': 'Hyderabad', 'Interview Country': 'India', 'Exam Type': 'GRE', 'Exam Score': 310.0, 'English Test Type': 'IELTS', 'English Test Score': 6.5, 'Grad Level': 'Bachelors (4 Years)', 'Grad Major': 'Mechanical Engineering', 'Grad GPA': 6.41, 'Grad Institute': 'SREENIDHI INSTITUTE OF SCIENCE AND TECHNOLOGY', 'Grad Country': 'India\n\n        Job Profile', 'Job Type': 'Nothing', 'Job Years': 0.0}
# 43 {'College': 'Missouri University of Science and Technology', 'Interview Outcome': 'Approved', 'Visa Attempt Number': 1.0, 'Interview Date': '2023-06-06', 'Interview Time': '08:40', 'Interview City': 'Delhi', 'Interview Country': 'No 12', 'Exam Type': 'GRE', 'Exam Score': 319.0, 'English Test Type': 'Dulingo', 'English Test Score': 120.0, 'Grad Level': 'Bachelors (4 Years)', 'Grad Major': 'Electronics and Communication Engineering', 'Grad GPA': 7.0, 'Grad Institute': 'Geethanjali collage of engineering and technology', 'Grad Country': 'India\n\n        Job Profile', 'Job Type': 'Jr Security analyst', 'Job Years': 0.7}
# 44 {'College': 'Saint Louis', 'Interview Outcome': 'Approved', 'Visa Attempt Number': 1.0, 'Interview Date': '2023-06-01', 'Interview Time': '09:45', 'Interview City': 'Hyderabad', 'Interview Country': 'India', 'Exam Type': 'GRE', 'Exam Score': 321.0, 'English Test Type': 'TOEFL', 'English Test Score': 96.0, 'Grad Level': 'Bachelors (4 Years)', 'Grad Major': 'Civil Engineer', 'Grad GPA': 8.32, 'Grad Institute': 'SASTRA University', 'Grad Country': 'India\n\n        Job Profile', 'Job Type': 'Data Analyst', 'Job Years': 1.3}
# 45 {'College': 'Valparaiso university', 'Interview Outcome': 'Rejected', 'Visa Attempt Number': 2.0, 'Interview Date': '2023-07-11', 'Interview Time': '10:30', 'Interview City': 'Chennai', 'Interview Country': 'India', 'Exam Type': 'Exempt', 'Exam Score': 0.0, 'English Test Type': 'Dulingo', 'English Test Score': 115.0, 'Grad Level': 'Bachelors-3', 'Grad Major': 'Computer Applications', 'Grad GPA': 8.33, 'Grad Institute': 'Osmania University', 'Grad Country': 'India\n\n        Job Profile', 'Job Type': nan, 'Job Years': 0.0}
# 46 {'College': 'Stevens Institute of Technology', 'Interview Outcome': 'Approved', 'Visa Attempt Number': 1.0, 'Interview Date': '2023-06-02', 'Interview Time': '11:20', 'Interview City': 'Delhi', 'Interview Country': 'India', 'Exam Type': 'GRE', 'Exam Score': 320.0, 'English Test Type': 'IELTS', 'English Test Score': 6.5, 'Grad Level': 'Bachelors (3 Years)', 'Grad Major': 'Bachelors of Commerce', 'Grad GPA': 7.8, 'Grad Institute': 'Osmania university', 'Grad Country': 'India\n\n        Job Profile', 'Job Type': 'Data analyst', 'Job Years': 1.5}
# 47 {'College': 'Saint Louis University', 'Interview Outcome': 'Approved', 'Visa Attempt Number': 1.0, 'Interview Date': '2023-06-07', 'Interview Time': '09:45', 'Interview City': 'Hyderabad', 'Interview Country': 'India', 'Exam Type': 'Exempt', 'Exam Score': 0.0, 'English Test Type': 'Dulingo', 'English Test Score': 110.0, 'Grad Level': 'Bachelors-4', 'Grad Major': 'Computer Science Engineering', 'Grad GPA': 7.01, 'Grad Institute': 'Swarna Bharathi Institute of Science and Technology', 'Grad Country': 'India\n\n        Job Profile', 'Job Type': 'Software Developer', 'Job Years': 1.6}
# 48 {'College': 'University of Missouri Kansas City', 'Interview Outcome': 'Approved', 'Visa Attempt Number': 1.0, 'Interview Date': '2023-06-07', 'Interview Time': '8:00AM', 'Interview City': 'Chennai', 'Interview Country': 'India', 'Exam Type': 'GRE', 'Exam Score': 320.0, 'English Test Type': 'TOEFL', 'English Test Score': 101.0, 'Grad Level': 'Bachelors-4', 'Grad Major': 'Information and Communication Technology', 'Grad GPA': 7.28, 'Grad Institute': 'SASTRA Deemed to be University', 'Grad Country': 'India\n\n        Job Profile', 'Job Type': 'Software Engineer', 'Job Years': 1.9}
# 49 {'College': 'New York Institute of Technology', 'Interview Outcome': 'Rejected', 'Visa Attempt Number': 2.0, 'Interview Date': '2023-07-10', 'Interview Time': '12:00', 'Interview City': 'Chennai', 'Interview Country': 'India', 'Exam Type': 'Others', 'Exam Score': 84.0, 'English Test Type': 'TOEFL', 'English Test Score': 84.0, 'Grad Level': 'Bachelors-3', 'Grad Major': 'Commerce', 'Grad GPA': 7.98, 'Grad Institute': 'Osmania University', 'Grad Country': 'India\n\n        Job Profile', 'Job Type': 'No Experience', 'Job Years': 0.0}
# 50 {'College': 'University of central missouri', 'Interview Outcome': 'Approved', 'Visa Attempt Number': 1.0, 'Interview Date': '2023-06-07', 'Interview Time': '11:50', 'Interview City': 'Delhi', 'Interview Country': 'India', 'Exam Type': 'GRE', 'Exam Score': 318.0, 'English Test Type': 'IELTS', 'English Test Score': 7.0, 'Grad Level': 'Bachelors-4', 'Grad Major': 'Electronics and communication engineering', 'Grad GPA': 6.3, 'Grad Institute': 'Lovely professional University', 'Grad Country': 'India\n\n        Job Profile', 'Job Type': 'Cloud data engineer', 'Job Years': 2.8}
# 51 {'College': 'Rutgers University', 'Interview Outcome': 'Approved', 'Visa Attempt Number': 1.0, 'Interview Date': '2023-06-07', 'Interview Time': '11:30', 'Interview City': 'Chennai', 'Interview Country': 'USA', 'Exam Type': 'Exempt', 'Exam Score': 0.0, 'English Test Type': 'TOEFL', 'English Test Score': 105.0, 'Grad Level': 'Masters', 'Grad Major': 'PHARM D', 'Grad GPA': 8.2, 'Grad Institute': 'JSS ACADEMY OF HIGHER EDUCATION AND RESEARCH', 'Grad Country': 'India\n\n        Job Profile', 'Job Type': 'Clinical Data Scientist', 'Job Years': 2.5}
# 52 {'College': 'University of Wisconsin', 'Interview Outcome': 'Approved', 'Visa Attempt Number': 1.0, 'Interview Date': '2023-06-07', 'Interview Time': '08:45', 'Interview City': 'Kolkata', 'Interview Country': 'Kolkata', 'Exam Type': 'Exempt', 'Exam Score': 0.0, 'English Test Type': 'Dulingo', 'English Test Score': 125.0, 'Grad Level': 'Bachelors (4 Years)', 'Grad Major': 'Computer Science and Engineering', 'Grad GPA': 6.63, 'Grad Institute': 'Lovely Professional University', 'Grad Country': 'India\n\n        Job Profile', 'Job Type': 'Software Engineer', 'Job Years': 2.0}
# 53 {'College': 'Saint Louis', 'Interview Outcome': 'Approved', 'Visa Attempt Number': 1.0, 'Interview Date': '2023-06-01', 'Interview Time': '09:45', 'Interview City': 'Hyderabad', 'Interview Country': 'India', 'Exam Type': 'GRE', 'Exam Score': 321.0, 'English Test Type': 'TOEFL', 'English Test Score': 96.0, 'Grad Level': 'Bachelors (4 Years)', 'Grad Major': 'Civil Engineer', 'Grad GPA': 8.32, 'Grad Institute': 'SASTRA University', 'Grad Country': 'India\n\n        Job Profile', 'Job Type': 'Data Analyst', 'Job Years': 1.3}
# 54 {'College': 'Dallas Baptist University', 'Interview Outcome': 'Approved', 'Visa Attempt Number': 1.0, 'Interview Date': '2023-06-07', 'Interview Time': '09:30', 'Interview City': 'Hyderabad', 'Interview Country': 'India', 'Exam Type': 'Exempt', 'Exam Score': 0.0, 'English Test Type': 'IELTS', 'English Test Score': 7.0, 'Grad Level': 'Bachelors (4 Years)', 'Grad Major': 'E.C.E', 'Grad GPA': 6.7, 'Grad Institute': 'JB Institute of Engineering and Technology', 'Grad Country': 'India\n\n        Job Profile', 'Job Type': 'Business systems Analyst', 'Job Years': 2.1}
# 55 {'College': 'Troy University', 'Interview Outcome': 'Rejected', 'Visa Attempt Number': 1.0, 'Interview Date': '2023-06-08', 'Interview Time': '10:30', 'Interview City': 'Hyderabad', 'Interview Country': 'India ', 'Exam Type': 'Exempt', 'Exam Score': 0.0, 'English Test Type': 'Dulingo', 'English Test Score': 125.0, 'Grad Level': 'Bachelors-4', 'Grad Major': 'computer science', 'Grad GPA': 6.5, 'Grad Institute': 'Jain University bangalore', 'Grad Country': 'india\n\n        Job Profile', 'Job Type': 'azure infrastructure engineer', 'Job Years': 2.5}
# 56 {'College': 'University of New Haven', 'Interview Outcome': 'Rejected', 'Visa Attempt Number': 1.0, 'Interview Date': '2023-07-10', 'Interview Time': '8:50', 'Interview City': 'Delhi', 'Interview Country': 'India ', 'Exam Type': 'Others', 'Exam Score': 61.0, 'English Test Type': 'Dulingo', 'English Test Score': 110.0, 'Grad Level': 'HighSchool', 'Grad Major': 'Going for computer and information sciences', 'Grad GPA': 7.5, 'Grad Institute': 'PKR Jain public school', 'Grad Country': 'India\n\n        Job Profile', 'Job Type': 'Study', 'Job Years': 18.0}
# 57 {'College': 'Pace University', 'Interview Outcome': 'Approved', 'Visa Attempt Number': 1.0, 'Interview Date': '2023-06-05', 'Interview Time': '09:10', 'Interview City': 'Mumbai', 'Interview Country': 'India', 'Exam Type': 'GRE', 'Exam Score': 296.0, 'English Test Type': 'IELTS', 'English Test Score': 7.0, 'Grad Level': 'Bachelors-4', 'Grad Major': 'Electronics and Telecommunications', 'Grad GPA': 7.7, 'Grad Institute': 'Yeshwantrao Chawan College of Engineering Nagpur', 'Grad Country': 'India\n\n        Job Profile', 'Job Type': 'Software Engineer', 'Job Years': 1.0}
# 58 {'College': 'NJIT', 'Interview Outcome': 'Approved', 'Visa Attempt Number': 1.0, 'Interview Date': '2023-06-07', 'Interview Time': '10:30', 'Interview City': 'Chennai', 'Interview Country': 'India', 'Exam Type': 'GRE', 'Exam Score': 324.0, 'English Test Type': 'TOEFL', 'English Test Score': 109.0, 'Grad Level': 'Bachelors (4 Years)', 'Grad Major': 'Computer Science', 'Grad GPA': 7.55, 'Grad Institute': 'SSIT', 'Grad Country': 'India\n\n        Job Profile', 'Job Type': 'Senior Analyst', 'Job Years': 1.9}
# 59 {'College': 'George mason University', 'Interview Outcome': 'Approved', 'Visa Attempt Number': 1.0, 'Interview Date': '2023-06-07', 'Interview Time': '11:50', 'Interview City': 'Delhi', 'Interview Country': 'India', 'Exam Type': 'GRE', 'Exam Score': 299.0, 'English Test Type': 'TOEFL', 'English Test Score': 87.0, 'Grad Level': 'Bachelors-4', 'Grad Major': 'Computer science and engineering', 'Grad GPA': 8.0, 'Grad Institute': 'Pes college of engineering', 'Grad Country': 'India\n\n        Job Profile', 'Job Type': 'Application development analyst', 'Job Years': 2.4}
# 60 {'College': 'Saint Louis University', 'Interview Outcome': 'Approved', 'Visa Attempt Number': 1.0, 'Interview Date': '2023-06-07', 'Interview Time': '09:45', 'Interview City': 'Hyderabad', 'Interview Country': 'India', 'Exam Type': 'Exempt', 'Exam Score': 0.0, 'English Test Type': 'Dulingo', 'English Test Score': 110.0, 'Grad Level': 'Bachelors-4', 'Grad Major': 'Computer Science Engineering', 'Grad GPA': 7.01, 'Grad Institute': 'Swarna Bharathi Institute of Science and Technology', 'Grad Country': 'India\n\n        Job Profile', 'Job Type': 'Software Developer', 'Job Years': 1.6}
# 61 {'College': 'University of Missouri Kansas City', 'Interview Outcome': 'Approved', 'Visa Attempt Number': 1.0, 'Interview Date': '2023-06-07', 'Interview Time': '8:00AM', 'Interview City': 'Chennai', 'Interview Country': 'India', 'Exam Type': 'GRE', 'Exam Score': 320.0, 'English Test Type': 'TOEFL', 'English Test Score': 101.0, 'Grad Level': 'Bachelors-4', 'Grad Major': 'Information and Communication Technology', 'Grad GPA': 7.28, 'Grad Institute': 'SASTRA Deemed to be University', 'Grad Country': 'India\n\n        Job Profile', 'Job Type': 'Software Engineer', 'Job Years': 1.9}
# 62 {'College': 'University of Colorado', 'Interview Outcome': 'Approved', 'Visa Attempt Number': 1.0, 'Interview Date': '2023-06-07', 'Interview Time': '10.30', 'Interview City': 'Chennai', 'Interview Country': 'India', 'Exam Type': 'Others', 'Exam Score': 0.0, 'English Test Type': 'IELTS', 'English Test Score': 7.5, 'Grad Level': 'Bachelors (4 Years)', 'Grad Major': 'Electrical and Electronics Engineering', 'Grad GPA': 8.8, 'Grad Institute': 'VIT Chennai', 'Grad Country': 'India\n\n        Job Profile', 'Job Type': 'Assistant Manager', 'Job Years': 4.0}
# 63 {'College': 'Missouri University of Science and Technology', 'Interview Outcome': 'Approved', 'Visa Attempt Number': 1.0, 'Interview Date': '2023-06-06', 'Interview Time': '08:40', 'Interview City': 'Delhi', 'Interview Country': 'No 12', 'Exam Type': 'GRE', 'Exam Score': 319.0, 'English Test Type': 'Dulingo', 'English Test Score': 120.0, 'Grad Level': 'Bachelors (4 Years)', 'Grad Major': 'Electronics and Communication Engineering', 'Grad GPA': 7.0, 'Grad Institute': 'Geethanjali collage of engineering and technology', 'Grad Country': 'India\n\n        Job Profile', 'Job Type': 'Jr Security analyst', 'Job Years': 0.7}
# 64 {'College': 'University of Dayton', 'Interview Outcome': 'Approved', 'Visa Attempt Number': 1.0, 'Interview Date': '2023-06-07', 'Interview Time': '11:50', 'Interview City': 'Delhi', 'Interview Country': 'India', 'Exam Type': 'GRE', 'Exam Score': 320.0, 'English Test Type': 'Dulingo', 'English Test Score': 125.0, 'Grad Level': 'Bachelors (4 Years)', 'Grad Major': 'Electronic and communication engineering', 'Grad GPA': 6.42, 'Grad Institute': 'GURUNANAK INSTITUTE OF TECHNICAL CAMPUS', 'Grad Country': 'India\n\n        Job Profile', 'Job Type': 'Intern', 'Job Years': 6.0}
# 65 {'College': 'Stevens institute of technology', 'Interview Outcome': 'Approved', 'Visa Attempt Number': 1.0, 'Interview Date': '2023-06-07', 'Interview Time': '10:30', 'Interview City': 'Hyderabad', 'Interview Country': 'India', 'Exam Type': 'GRE', 'Exam Score': 310.0, 'English Test Type': 'IELTS', 'English Test Score': 6.5, 'Grad Level': 'Bachelors (4 Years)', 'Grad Major': 'Mechanical Engineering', 'Grad GPA': 6.41, 'Grad Institute': 'SREENIDHI INSTITUTE OF SCIENCE AND TECHNOLOGY', 'Grad Country': 'India\n\n        Job Profile', 'Job Type': 'Nothing', 'Job Years': 0.0}
# 66 {'College': 'Auburn university', 'Interview Outcome': 'Rejected', 'Visa Attempt Number': 1.0, 'Interview Date': '2023-06-01', 'Interview Time': '11:00', 'Interview City': 'Chennai', 'Interview Country': 'India', 'Exam Type': 'Exempt', 'Exam Score': 0.0, 'English Test Type': 'TOEFL', 'English Test Score': 82.0, 'Grad Level': 'Bachelors (4 Years)', 'Grad Major': 'Computer Science', 'Grad GPA': 7.1, 'Grad Institute': 'Nova college of eng', 'Grad Country': 'India\n\n        Job Profile', 'Job Type': 'Software developer', 'Job Years': 3.5}
# 67 {'College': 'Suny Albany', 'Interview Outcome': 'Approved', 'Visa Attempt Number': 1.0, 'Interview Date': '2023-06-08', 'Interview Time': '11:40', 'Interview City': 'Delhi', 'Interview Country': 'India', 'Exam Type': 'GRE', 'Exam Score': 322.0, 'English Test Type': 'Dulingo', 'English Test Score': 135.0, 'Grad Level': 'Bachelors-4', 'Grad Major': 'Electronics and communication engineering', 'Grad GPA': 8.02, 'Grad Institute': 'PvP Siddhartha institute of technology', 'Grad Country': 'India\n\n        Job Profile', 'Job Type': 'Fresher', 'Job Years': 0.0}
# 68 {'College': 'Illinois institute of technology', 'Interview Outcome': 'Rejected', 'Visa Attempt Number': 1.0, 'Interview Date': '2023-07-05', 'Interview Time': '12:00', 'Interview City': 'Chennai', 'Interview Country': 'India', 'Exam Type': 'Exempt', 'Exam Score': 0.0, 'English Test Type': 'IELTS', 'English Test Score': 6.5, 'Grad Level': 'Bachelors (4 Years)', 'Grad Major': 'Mechanical engineering', 'Grad GPA': 7.7, 'Grad Institute': 'VTU', 'Grad Country': 'India\n\n        Job Profile', 'Job Type': 'Associate', 'Job Years': 2.7}
# 69 {'College': 'Suny Albany', 'Interview Outcome': 'Approved', 'Visa Attempt Number': 1.0, 'Interview Date': '2023-06-08', 'Interview Time': '11:40', 'Interview City': 'Delhi', 'Interview Country': 'India', 'Exam Type': 'GRE', 'Exam Score': 322.0, 'English Test Type': 'Dulingo', 'English Test Score': 135.0, 'Grad Level': 'Bachelors-4', 'Grad Major': 'Electronics and communication engineering', 'Grad GPA': 8.02, 'Grad Institute': 'PvP Siddhartha institute of technology', 'Grad Country': 'India\n\n        Job Profile', 'Job Type': 'Fresher', 'Job Years': 0.0}
# 70 {'College': 'THE Jhons Hopkins University', 'Interview Outcome': 'Approved', 'Visa Attempt Number': 1.0, 'Interview Date': '2023-06-07', 'Interview Time': '8:00', 'Interview City': 'Hyderabad', 'Interview Country': 'India', 'Exam Type': 'Others', 'Exam Score': 0.0, 'English Test Type': 'TOEFL', 'English Test Score': 104.0, 'Grad Level': 'Others', 'Grad Major': 'M.B.B.S', 'Grad GPA': 4.0, 'Grad Institute': 'KLE', 'Grad Country': 'India\n\n        Job Profile', 'Job Type': 'Doctor', 'Job Years': 1.0}
# 71 {'College': 'Valparaiso university', 'Interview Outcome': 'Rejected', 'Visa Attempt Number': 2.0, 'Interview Date': '2023-07-11', 'Interview Time': '10:30', 'Interview City': 'Chennai', 'Interview Country': 'India', 'Exam Type': 'Exempt', 'Exam Score': 0.0, 'English Test Type': 'Dulingo', 'English Test Score': 115.0, 'Grad Level': 'Bachelors-3', 'Grad Major': 'Computer Applications', 'Grad GPA': 8.33, 'Grad Institute': 'Osmania University', 'Grad Country': 'India\n\n        Job Profile', 'Job Type': nan, 'Job Years': 0.0}
# 72 {'College': 'Harrisburg univeristy', 'Interview Outcome': 'Rejected', 'Visa Attempt Number': 1.0, 'Interview Date': '2023-07-10', 'Interview Time': '09:50', 'Interview City': 'Delhi', 'Interview Country': 'India', 'Exam Type': 'Others', 'Exam Score': 6.0, 'English Test Type': 'Dulingo', 'English Test Score': 130.0, 'Grad Level': 'Bachelors-4', 'Grad Major': 'Electrical and electronics eng', 'Grad GPA': 6.4, 'Grad Institute': 'Jntuh', 'Grad Country': 'India\n\n        Job Profile', 'Job Type': 'Business development team member', 'Job Years': 0.9}
# 73 {'College': 'Illinois Institute of Technology', 'Interview Outcome': 'Approved', 'Visa Attempt Number': 1.0, 'Interview Date': '2023-06-07', 'Interview Time': '8:00', 'Interview City': 'Hyderabad', 'Interview Country': 'India ', 'Exam Type': 'GRE', 'Exam Score': 317.0, 'English Test Type': 'IELTS', 'English Test Score': 6.5, 'Grad Level': 'Bachelors-4', 'Grad Major': 'Mechanical Engineering', 'Grad GPA': 8.1, 'Grad Institute': 'Malla Reddy Engineering College', 'Grad Country': 'India\n\n        Job Profile', 'Job Type': 'Fresher', 'Job Years': 0.0}
# 74 {'College': 'New York Institute of Technology', 'Interview Outcome': 'Rejected', 'Visa Attempt Number': 2.0, 'Interview Date': '2023-07-10', 'Interview Time': '12:00', 'Interview City': 'Chennai', 'Interview Country': 'India', 'Exam Type': 'Others', 'Exam Score': 84.0, 'English Test Type': 'TOEFL', 'English Test Score': 84.0, 'Grad Level': 'Bachelors-3', 'Grad Major': 'Commerce', 'Grad GPA': 7.98, 'Grad Institute': 'Osmania University', 'Grad Country': 'India\n\n        Job Profile', 'Job Type': 'No Experience', 'Job Years': 0.0}
# 75 {'College': 'Concordia St Paul university', 'Interview Outcome': 'Approved', 'Visa Attempt Number': 1.0, 'Interview Date': '2023-06-07', 'Interview Time': '11:30', 'Interview City': 'Delhi', 'Interview Country': 'India', 'Exam Type': 'Others', 'Exam Score': 0.0, 'English Test Type': 'TOEFL', 'English Test Score': 90.0, 'Grad Level': 'Bachelors (4 Years)', 'Grad Major': 'Electronics and Communication Engineering', 'Grad GPA': 7.22, 'Grad Institute': 'Sai Tirumala NVR Engineering College', 'Grad Country': 'India\n\n        Job Profile', 'Job Type': 'IT Analyst', 'Job Years': 1.0}
# 76 {'College': 'Hofstra University', 'Interview Outcome': 'Approved', 'Visa Attempt Number': 1.0, 'Interview Date': '2023-06-07', 'Interview Time': '9:50', 'Interview City': 'New Delhi', 'Interview Country': 'New Delhi ', 'Exam Type': 'GRE', 'Exam Score': 315.0, 'English Test Type': 'TOEFL', 'English Test Score': 89.0, 'Grad Level': 'Bachelors (4 Years)', 'Grad Major': 'B pharmacy', 'Grad GPA': 7.0, 'Grad Institute': 'Anurag group of institutions', 'Grad Country': 'India\n\n        Job Profile', 'Job Type': 'Medical coder', 'Job Years': 1.0}
# 77 {'College': 'NJIT', 'Interview Outcome': 'Approved', 'Visa Attempt Number': 1.0, 'Interview Date': '2023-06-07', 'Interview Time': '10:30', 'Interview City': 'Chennai', 'Interview Country': 'India', 'Exam Type': 'GRE', 'Exam Score': 324.0, 'English Test Type': 'TOEFL', 'English Test Score': 109.0, 'Grad Level': 'Bachelors (4 Years)', 'Grad Major': 'Computer Science', 'Grad GPA': 7.55, 'Grad Institute': 'SSIT', 'Grad Country': 'India\n\n        Job Profile', 'Job Type': 'Senior Analyst', 'Job Years': 1.9}
# 78 {'College': 'George mason University', 'Interview Outcome': 'Approved', 'Visa Attempt Number': 1.0, 'Interview Date': '2023-06-07', 'Interview Time': '11:50', 'Interview City': 'Delhi', 'Interview Country': 'India', 'Exam Type': 'GRE', 'Exam Score': 299.0, 'English Test Type': 'TOEFL', 'English Test Score': 87.0, 'Grad Level': 'Bachelors-4', 'Grad Major': 'Computer science and engineering', 'Grad GPA': 8.0, 'Grad Institute': 'Pes college of engineering', 'Grad Country': 'India\n\n        Job Profile', 'Job Type': 'Application development analyst', 'Job Years': 2.4}
# 79 {'College': 'Harrisburg univeristy', 'Interview Outcome': 'Rejected', 'Visa Attempt Number': 1.0, 'Interview Date': '2023-07-10', 'Interview Time': '09:50', 'Interview City': 'Delhi', 'Interview Country': 'India', 'Exam Type': 'Others', 'Exam Score': 6.0, 'English Test Type': 'Dulingo', 'English Test Score': 130.0, 'Grad Level': 'Bachelors-4', 'Grad Major': 'Electrical and electronics eng', 'Grad GPA': 6.4, 'Grad Institute': 'Jntuh', 'Grad Country': 'India\n\n        Job Profile', 'Job Type': 'Business development team member', 'Job Years': 0.9}
# 80 {'College': 'NJIT', 'Interview Outcome': 'Approved', 'Visa Attempt Number': 1.0, 'Interview Date': '2023-06-07', 'Interview Time': '10:30', 'Interview City': 'Chennai', 'Interview Country': 'India', 'Exam Type': 'GRE', 'Exam Score': 324.0, 'English Test Type': 'TOEFL', 'English Test Score': 109.0, 'Grad Level': 'Bachelors (4 Years)', 'Grad Major': 'Computer Science', 'Grad GPA': 7.55, 'Grad Institute': 'SSIT', 'Grad Country': 'India\n\n        Job Profile', 'Job Type': 'Senior Analyst', 'Job Years': 1.9}
# 81 {'College': 'Saint Louis', 'Interview Outcome': 'Approved', 'Visa Attempt Number': 1.0, 'Interview Date': '2023-06-01', 'Interview Time': '09:45', 'Interview City': 'Hyderabad', 'Interview Country': 'India', 'Exam Type': 'GRE', 'Exam Score': 321.0, 'English Test Type': 'TOEFL', 'English Test Score': 96.0, 'Grad Level': 'Bachelors (4 Years)', 'Grad Major': 'Civil Engineer', 'Grad GPA': 8.32, 'Grad Institute': 'SASTRA University', 'Grad Country': 'India\n\n        Job Profile', 'Job Type': 'Data Analyst', 'Job Years': 1.3}
# 82 {'College': 'Lewis university location Romeoville', 'Interview Outcome': 'Rejected', 'Visa Attempt Number': 1.0, 'Interview Date': '2023-07-06', 'Interview Time': '8:30', 'Interview City': 'Mumbai', 'Interview Country': 'Usa', 'Exam Type': 'Exempt', 'Exam Score': 160.0, 'English Test Type': 'Dulingo', 'English Test Score': 145.0, 'Grad Level': 'Bachelors-3', 'Grad Major': 'B.Com', 'Grad GPA': 8.1, 'Grad Institute': 'Osmania university', 'Grad Country': 'India \n\n        Job Profile', 'Job Type': 'Gampact company', 'Job Years': 2.5}
# 83 {'College': 'Stevens institute of technology', 'Interview Outcome': 'Approved', 'Visa Attempt Number': 1.0, 'Interview Date': '2023-06-07', 'Interview Time': '10:30', 'Interview City': 'Hyderabad', 'Interview Country': 'India', 'Exam Type': 'GRE', 'Exam Score': 310.0, 'English Test Type': 'IELTS', 'English Test Score': 6.5, 'Grad Level': 'Bachelors (4 Years)', 'Grad Major': 'Mechanical Engineering', 'Grad GPA': 6.41, 'Grad Institute': 'SREENIDHI INSTITUTE OF SCIENCE AND TECHNOLOGY', 'Grad Country': 'India\n\n        Job Profile', 'Job Type': 'Nothing', 'Job Years': 0.0}
# 84 {'College': 'New York Institute of Technology', 'Interview Outcome': 'Rejected', 'Visa Attempt Number': 2.0, 'Interview Date': '2023-07-10', 'Interview Time': '12:00', 'Interview City': 'Chennai', 'Interview Country': 'India', 'Exam Type': 'Others', 'Exam Score': 84.0, 'English Test Type': 'TOEFL', 'English Test Score': 84.0, 'Grad Level': 'Bachelors-3', 'Grad Major': 'Commerce', 'Grad GPA': 7.98, 'Grad Institute': 'Osmania University', 'Grad Country': 'India\n\n        Job Profile', 'Job Type': 'No Experience', 'Job Years': 0.0}
# ...
# 123 {'College': 'University of north Texas', 'Interview Outcome': 'Approved', 'Visa Attempt Number': 1.0, 'Interview Date': '2023-06-08', 'Interview Time': '08:30', 'Interview City': 'Chennai', 'Interview Country': 'India ', 'Exam Type': 'GRE', 'Exam Score': 316.0, 'English Test Type': 'Dulingo', 'English Test Score': 110.0, 'Grad Level': 'Bachelors-4', 'Grad Major': 'computer science and engineering', 'Grad GPA': 7.3, 'Grad Institute': 'Mallareddy engineering college for women', 'Grad Country': 'India\n\n        Job Profile', 'Job Type': nan, 'Job Years': 1.8}
# 124 {'College': 'Hofstra University', 'Interview Outcome': 'Approved', 'Visa Attempt Number': 1.0, 'Interview Date': '2023-06-07', 'Interview Time': '9:50', 'Interview City': 'New Delhi', 'Interview Country': 'New Delhi ', 'Exam Type': 'GRE', 'Exam Score': 315.0, 'English Test Type': 'TOEFL', 'English Test Score': 89.0, 'Grad Level': 'Bachelors (4 Years)', 'Grad Major': 'B pharmacy', 'Grad GPA': 7.0, 'Grad Institute': 'Anurag group of institutions', 'Grad Country': 'India\n\n        Job Profile', 'Job Type': 'Medical coder', 'Job Years': 1.0}
# 125 {'College': 'Lewis university location Romeoville', 'Interview Outcome': 'Rejected', 'Visa Attempt Number': 1.0, 'Interview Date': '2023-07-06', 'Interview Time': '8:30', 'Interview City': 'Mumbai', 'Interview Country': 'Usa', 'Exam Type': 'Exempt', 'Exam Score': 160.0, 'English Test Type': 'Dulingo', 'English Test Score': 145.0, 'Grad Level': 'Bachelors-3', 'Grad Major': 'B.Com', 'Grad GPA': 8.1, 'Grad Institute': 'Osmania university', 'Grad Country': 'India \n\n        Job Profile', 'Job Type': 'Gampact company', 'Job Years': 2.5}
# 126 {'College': 'Lewis University', 'Interview Outcome': 'Approved', 'Visa Attempt Number': 1.0, 'Interview Date': '2023-06-06', 'Interview Time': '09.30', 'Interview City': 'Mumbai', 'Interview Country': 'India', 'Exam Type': 'Exempt', 'Exam Score': 0.0, 'English Test Type': 'Dulingo', 'English Test Score': 120.0, 'Grad Level': 'Bachelors (3 Years)', 'Grad Major': 'Commerce', 'Grad GPA': 6.0, 'Grad Institute': 'Osmania University', 'Grad Country': 'India\n\n        Job Profile', 'Job Type': 'IT Support Specialist', 'Job Years': 9.6}
# 127 {'College': 'Stevens institute of technology', 'Interview Outcome': 'Approved', 'Visa Attempt Number': 1.0, 'Interview Date': '2023-06-07', 'Interview Time': '10:30', 'Interview City': 'Hyderabad', 'Interview Country': 'India', 'Exam Type': 'GRE', 'Exam Score': 310.0, 'English Test Type': 'IELTS', 'English Test Score': 6.5, 'Grad Level': 'Bachelors (4 Years)', 'Grad Major': 'Mechanical Engineering', 'Grad GPA': 6.41, 'Grad Institute': 'SREENIDHI INSTITUTE OF SCIENCE AND TECHNOLOGY', 'Grad Country': 'India\n\n        Job Profile', 'Job Type': 'Nothing', 'Job Years': 0.0}
# 128 {'College': 'Babson College', 'Interview Outcome': 'Approved', 'Visa Attempt Number': 1.0, 'Interview Date': '2023-06-07', 'Interview Time': '9:30', 'Interview City': 'Mumbai', 'Interview Country': 'India', 'Exam Type': 'Exempt', 'Exam Score': 0.0, 'English Test Type': 'IELTS', 'English Test Score': 7.0, 'Grad Level': 'Masters', 'Grad Major': 'Computer Science Engineering', 'Grad GPA': 7.65, 'Grad Institute': 'NIT Allahabad', 'Grad Country': 'India\n\n        Job Profile', 'Job Type': 'Senior Software Engineer', 'Job Years': 5.0}
# 129 {'College': 'Missouri State University', 'Interview Outcome': 'Rejected', 'Visa Attempt Number': 2.0, 'Interview Date': '2023-07-11', 'Interview Time': '10:30', 'Interview City': 'Chennai', 'Interview Country': 'India', 'Exam Type': 'Others', 'Exam Score': 6.0, 'English Test Type': 'IELTS', 'English Test Score': 6.0, 'Grad Level': 'Bachelors-3', 'Grad Major': "Bachelor's In Hotel Management", 'Grad GPA': 8.36, 'Grad Institute': 'Sun international institute of management and technology', 'Grad Country': 'India\n\n        Job Profile', 'Job Type': 'Genpact as a Process Associate', 'Job Years': 0.6}
# 130 {'College': 'Harrisburg univeristy', 'Interview Outcome': 'Rejected', 'Visa Attempt Number': 1.0, 'Interview Date': '2023-07-10', 'Interview Time': '09:50', 'Interview City': 'Delhi', 'Interview Country': 'India', 'Exam Type': 'Others', 'Exam Score': 6.0, 'English Test Type': 'Dulingo', 'English Test Score': 130.0, 'Grad Level': 'Bachelors-4', 'Grad Major': 'Electrical and electronics eng', 'Grad GPA': 6.4, 'Grad Institute': 'Jntuh', 'Grad Country': 'India\n\n        Job Profile', 'Job Type': 'Business development team member', 'Job Years': 0.9}
# 131 {'College': 'Saint Louis', 'Interview Outcome': 'Approved', 'Visa Attempt Number': 1.0, 'Interview Date': '2023-06-01', 'Interview Time': '09:45', 'Interview City': 'Hyderabad', 'Interview Country': 'India', 'Exam Type': 'GRE', 'Exam Score': 321.0, 'English Test Type': 'TOEFL', 'English Test Score': 96.0, 'Grad Level': 'Bachelors (4 Years)', 'Grad Major': 'Civil Engineer', 'Grad GPA': 8.32, 'Grad Institute': 'SASTRA University', 'Grad Country': 'India\n\n        Job Profile', 'Job Type': 'Data Analyst', 'Job Years': 1.3}
# 132 {'College': 'Saint Louis University', 'Interview Outcome': 'Rejected', 'Visa Attempt Number': 1.0, 'Interview Date': '2023-07-06', 'Interview Time': '10:00', 'Interview City': 'Chennai', 'Interview Country': 'India ', 'Exam Type': 'GRE', 'Exam Score': 316.0, 'English Test Type': 'Dulingo', 'English Test Score': 120.0, 'Grad Level': 'Bachelors-4', 'Grad Major': 'Information technology', 'Grad GPA': 8.77, 'Grad Institute': 'Vishnu Institute of technology', 'Grad Country': 'India \n\n        Job Profile', 'Job Type': 'Recently graduated', 'Job Years': 0.0}
# 133 {'College': 'Pace University', 'Interview Outcome': 'Approved', 'Visa Attempt Number': 1.0, 'Interview Date': '2023-06-05', 'Interview Time': '09:10', 'Interview City': 'Mumbai', 'Interview Country': 'India', 'Exam Type': 'GRE', 'Exam Score': 296.0, 'English Test Type': 'IELTS', 'English Test Score': 7.0, 'Grad Level': 'Bachelors-4', 'Grad Major': 'Electronics and Telecommunications', 'Grad GPA': 7.7, 'Grad Institute': 'Yeshwantrao Chawan College of Engineering Nagpur', 'Grad Country': 'India\n\n        Job Profile', 'Job Type': 'Software Engineer', 'Job Years': 1.0}
# 134 {'College': 'Stevens institute of technology', 'Interview Outcome': 'Approved', 'Visa Attempt Number': 1.0, 'Interview Date': '2023-06-07', 'Interview Time': '10:30', 'Interview City': 'Hyderabad', 'Interview Country': 'India', 'Exam Type': 'GRE', 'Exam Score': 310.0, 'English Test Type': 'IELTS', 'English Test Score': 6.5, 'Grad Level': 'Bachelors (4 Years)', 'Grad Major': 'Mechanical Engineering', 'Grad GPA': 6.41, 'Grad Institute': 'SREENIDHI INSTITUTE OF SCIENCE AND TECHNOLOGY', 'Grad Country': 'India\n\n        Job Profile', 'Job Type': 'Nothing', 'Job Years': 0.0}
# 135 {'College': 'University of Missouri Kansas City', 'Interview Outcome': 'Approved', 'Visa Attempt Number': 1.0, 'Interview Date': '2023-06-07', 'Interview Time': '8:00AM', 'Interview City': 'Chennai', 'Interview Country': 'India', 'Exam Type': 'GRE', 'Exam Score': 320.0, 'English Test Type': 'TOEFL', 'English Test Score': 101.0, 'Grad Level': 'Bachelors-4', 'Grad Major': 'Information and Communication Technology', 'Grad GPA': 7.28, 'Grad Institute': 'SASTRA Deemed to be University', 'Grad Country': 'India\n\n        Job Profile', 'Job Type': 'Software Engineer', 'Job Years': 1.9}
# 136 {'College': 'Concordia St Paul university', 'Interview Outcome': 'Approved', 'Visa Attempt Number': 1.0, 'Interview Date': '2023-06-07', 'Interview Time': '11:30', 'Interview City': 'Delhi', 'Interview Country': 'India', 'Exam Type': 'Others', 'Exam Score': 0.0, 'English Test Type': 'TOEFL', 'English Test Score': 90.0, 'Grad Level': 'Bachelors (4 Years)', 'Grad Major': 'Electronics and Communication Engineering', 'Grad GPA': 7.22, 'Grad Institute': 'Sai Tirumala NVR Engineering College', 'Grad Country': 'India\n\n        Job Profile', 'Job Type': 'IT Analyst', 'Job Years': 1.0}
# 137 {'College': 'Troy University', 'Interview Outcome': 'Rejected', 'Visa Attempt Number': 1.0, 'Interview Date': '2023-06-08', 'Interview Time': '10:30', 'Interview City': 'Hyderabad', 'Interview Country': 'India ', 'Exam Type': 'Exempt', 'Exam Score': 0.0, 'English Test Type': 'Dulingo', 'English Test Score': 125.0, 'Grad Level': 'Bachelors-4', 'Grad Major': 'computer science', 'Grad GPA': 6.5, 'Grad Institute': 'Jain University bangalore', 'Grad Country': 'india\n\n        Job Profile', 'Job Type': 'azure infrastructure engineer', 'Job Years': 2.5}
# 138 {'College': 'University of Colorado', 'Interview Outcome': 'Approved', 'Visa Attempt Number': 1.0, 'Interview Date': '2023-06-07', 'Interview Time': '10.30', 'Interview City': 'Chennai', 'Interview Country': 'India', 'Exam Type': 'Others', 'Exam Score': 0.0, 'English Test Type': 'IELTS', 'English Test Score': 7.5, 'Grad Level': 'Bachelors (4 Years)', 'Grad Major': 'Electrical and Electronics Engineering', 'Grad GPA': 8.8, 'Grad Institute': 'VIT Chennai', 'Grad Country': 'India\n\n        Job Profile', 'Job Type': 'Assistant Manager', 'Job Years': 4.0}
# 139 {'College': 'Dallas Baptist University', 'Interview Outcome': 'Approved', 'Visa Attempt Number': 1.0, 'Interview Date': '2023-06-07', 'Interview Time': '09:30', 'Interview City': 'Hyderabad', 'Interview Country': 'India', 'Exam Type': 'Exempt', 'Exam Score': 0.0, 'English Test Type': 'IELTS', 'English Test Score': 7.0, 'Grad Level': 'Bachelors (4 Years)', 'Grad Major': 'E.C.E', 'Grad GPA': 6.7, 'Grad Institute': 'JB Institute of Engineering and Technology', 'Grad Country': 'India\n\n        Job Profile', 'Job Type': 'Business systems Analyst', 'Job Years': 2.1}
# 140 {'College': 'Illinois institute of technology', 'Interview Outcome': 'Rejected', 'Visa Attempt Number': 1.0, 'Interview Date': '2023-07-05', 'Interview Time': '12:00', 'Interview City': 'Chennai', 'Interview Country': 'India', 'Exam Type': 'Exempt', 'Exam Score': 0.0, 'English Test Type': 'IELTS', 'English Test Score': 6.5, 'Grad Level': 'Bachelors (4 Years)', 'Grad Major': 'Mechanical engineering', 'Grad GPA': 7.7, 'Grad Institute': 'VTU', 'Grad Country': 'India\n\n        Job Profile', 'Job Type': 'Associate', 'Job Years': 2.7}
# 141 {'College': 'Missouri State University', 'Interview Outcome': 'Rejected', 'Visa Attempt Number': 2.0, 'Interview Date': '2023-07-11', 'Interview Time': '10:30', 'Interview City': 'Chennai', 'Interview Country': 'India', 'Exam Type': 'Others', 'Exam Score': 6.0, 'English Test Type': 'IELTS', 'English Test Score': 6.0, 'Grad Level': 'Bachelors-3', 'Grad Major': "Bachelor's In Hotel Management", 'Grad GPA': 8.36, 'Grad Institute': 'Sun international institute of management and technology', 'Grad Country': 'India\n\n        Job Profile', 'Job Type': 'Genpact as a Process Associate', 'Job Years': 0.6}
# 142 {'College': 'University of Missouri Kansas City', 'Interview Outcome': 'Approved', 'Visa Attempt Number': 1.0, 'Interview Date': '2023-06-07', 'Interview Time': '8:00AM', 'Interview City': 'Chennai', 'Interview Country': 'India', 'Exam Type': 'GRE', 'Exam Score': 320.0, 'English Test Type': 'TOEFL', 'English Test Score': 101.0, 'Grad Level': 'Bachelors-4', 'Grad Major': 'Information and Communication Technology', 'Grad GPA': 7.28, 'Grad Institute': 'SASTRA Deemed to be University', 'Grad Country': 'India\n\n        Job Profile', 'Job Type': 'Software Engineer', 'Job Years': 1.9}
# 143 {'College': 'Concordia St Paul university', 'Interview Outcome': 'Approved', 'Visa Attempt Number': 1.0, 'Interview Date': '2023-06-07', 'Interview Time': '11:30', 'Interview City': 'Delhi', 'Interview Country': 'India', 'Exam Type': 'Others', 'Exam Score': 0.0, 'English Test Type': 'TOEFL', 'English Test Score': 90.0, 'Grad Level': 'Bachelors (4 Years)', 'Grad Major': 'Electronics and Communication Engineering', 'Grad GPA': 7.22, 'Grad Institute': 'Sai Tirumala NVR Engineering College', 'Grad Country': 'India\n\n        Job Profile', 'Job Type': 'IT Analyst', 'Job Years': 1.0}
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-9-617d9512afdb> in <module>
# ----> 1 for count, i in enumerate(consumer):
#       2     with s3.open("s3://telebot-snehit/teleBot-row_{}.json".format(count), 'w') as file:
#       3         json.dump(i.value, file)
#       4         print(count, i.value)
#
# c:\users\vsneh\appdata\local\programs\python\python37\lib\site-packages\kafka\consumer\group.py in __next__(self)
#    1191             return self.next_v1()
#    1192         else:
# -> 1193             return self.next_v2()
#    1194
#    1195     def next_v2(self):
#
# c:\users\vsneh\appdata\local\programs\python\python37\lib\site-packages\kafka\consumer\group.py in next_v2(self)
#    1199                 self._iterator = self._message_generator_v2()
#    1200             try:
# -> 1201                 return next(self._iterator)
#    1202             except StopIteration:
#    1203                 self._iterator = None
#
# c:\users\vsneh\appdata\local\programs\python\python37\lib\site-packages\kafka\consumer\group.py in _message_generator_v2(self)
#    1114     def _message_generator_v2(self):
#    1115         timeout_ms = 1000 * (self._consumer_timeout - time.time())
# -> 1116         record_map = self.poll(timeout_ms=timeout_ms, update_offsets=False)
#    1117         for tp, records in six.iteritems(record_map):
#    1118             # Generators are stateful, and it is possible that the tp / records
#
# c:\users\vsneh\appdata\local\programs\python\python37\lib\site-packages\kafka\consumer\group.py in poll(self, timeout_ms, max_records, update_offsets)
#     653         remaining = timeout_ms
#     654         while True:
# --> 655             records = self._poll_once(remaining, max_records, update_offsets=update_offsets)
#     656             if records:
#     657                 return records
#
# c:\users\vsneh\appdata\local\programs\python\python37\lib\site-packages\kafka\consumer\group.py in _poll_once(self, timeout_ms, max_records, update_offsets)
#     700
#     701         timeout_ms = min(timeout_ms, self._coordinator.time_to_next_poll() * 1000)
# --> 702         self._client.poll(timeout_ms=timeout_ms)
#     703         # after the long poll, we should check whether the group needs to rebalance
#     704         # prior to returning data so that the group can stabilize faster
#
# c:\users\vsneh\appdata\local\programs\python\python37\lib\site-packages\kafka\client_async.py in poll(self, timeout_ms, future)
#     600                     timeout = max(0, timeout)  # avoid negative timeouts
#     601
# --> 602                 self._poll(timeout / 1000)
#     603
#     604             # called without the lock to avoid deadlock potential
#
# c:\users\vsneh\appdata\local\programs\python\python37\lib\site-packages\kafka\client_async.py in _poll(self, timeout)
#     632
#     633         start_select = time.time()
# --> 634         ready = self._selector.select(timeout)
#     635         end_select = time.time()
#     636         if self._sensors:
#
# c:\users\vsneh\appdata\local\programs\python\python37\lib\selectors.py in select(self, timeout)
#     321         ready = []
#     322         try:
# --> 323             r, w, _ = self._select(self._readers, self._writers, [], timeout)
#     324         except InterruptedError:
#     325             return ready
#
# c:\users\vsneh\appdata\local\programs\python\python37\lib\selectors.py in _select(self, r, w, _, timeout)
#     312     if sys.platform == 'win32':
#     313         def _select(self, r, w, _, timeout=None):
# --> 314             r, w, x = select.select(r, w, w, timeout)
#     315             return r, w + x, []
#     316     else:
#
# KeyboardInterrupt:
